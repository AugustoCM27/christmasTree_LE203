# %%
# MA2 - LE203 - Cálculo II - 08/01/2021
# Profa. Priscila Berbert Rampazzo

# Integrantes:

# Augusto Chebel Machado	           		RA: 231762
# Lucas Massabni Busnardo			          RA: 182516
# Nathan Czelusniak de Siqueira	 	      RA: 186041
# Nicolas Keichi Matsuse Shirai        	RA: 186143
# Vitor Janerilo Cardoso                RA: 195228

# Árvore de Natal

# jupyter
# %matplotlib notebook  
# colab
# %matplotlib inline   
# bibliotecas
from mpl_toolkits import mplot3d
import numpy as np
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(10,10))
ax = plt.axes(projection='3d')

# cilíndro para tronco 
a = 2
b = 10
c = 0
# parâmetros
theta = np.linspace(0, 2*np.pi, 30)
z = np.linspace(b, c, 30)
z, theta = np.meshgrid(z, theta)
# parametrização
x = a*np.cos(theta)
y = a*np.sin(theta) 
z = z
# gráfico
ax.plot_surface(x, y, z, alpha=1, color='saddlebrown')

# cone para árvore 1
a = 20
b = 10
c = 20  # comprimento
# parâmetros
theta = np.linspace(0, 2*np.pi, 30)
r = np.linspace(0, 1, 30)
theta, r = np.meshgrid(theta, r)
# parametrização
x = b*r*np.cos(theta)
y = b*r*np.sin(theta)
z = -c*r
#gráfico
ax.plot_surface(x, y, z+25, alpha=0.6, color='forestgreen')

# cone para árvore 2
a = 20
b = 10
c = 18  # comprimento
# parâmetros
theta = np.linspace(0, 2*np.pi, 30)
r = np.linspace(0, 1, 30)
theta, r = np.meshgrid(theta, r)
# parametrização
x = b*r*np.cos(theta)
y = b*r*np.sin(theta)
z = -c*r
#gráfico
ax.plot_surface(x, y, z+25, alpha=0.5, color='forestgreen')

# cone para árvore 3
a = 20
b = 10
c = 16  # comprimento
# parâmetros
theta = np.linspace(0, 2*np.pi, 30)
r = np.linspace(0, 1, 30)
theta, r = np.meshgrid(theta, r)
# parametrização
x = b*r*np.cos(theta)
y = b*r*np.sin(theta)
z = -c*r
#gráfico
ax.plot_surface(x, y, z+25, alpha=0.4, color='springgreen')

# cone para árvore 4
a = 20
b = 10
c = 14  # comprimento
# parâmetros
theta = np.linspace(0, 2*np.pi, 30)
r = np.linspace(0, 1, 30)
theta, r = np.meshgrid(theta, r)
# parametrização
x = b*r*np.cos(theta)
y = b*r*np.sin(theta)
z = -c*r
#gráfico
ax.plot_surface(x, y, z+25, alpha=0.3, color='forestgreen')

# plano para base do chão
a = -20
b = 20
c = -20
d = 20
e = -0.5
# parâmetros
u = np.linspace(a, b, 30)
v = np.linspace(c, d, 30)
u, v = np.meshgrid(u, v)
# parametrização
x = u
y = v
z = e + 0*u 
# gráfico
ax.plot_surface(x, y, z, alpha=0.6, color='navajowhite')

# plano para base inferior da árvore 1
a = 10
e = 0
# parâmetros
theta = np.linspace(0, 2*np.pi, 30)
r = np.linspace(0, a, 30)
r, theta = np.meshgrid(r, theta)
# parametrização
x = r*np.cos(theta)
y = r*np.sin(theta)
z = e + 0*r
# gráfico
ax.plot_surface(x, y, z+5, alpha=1, color='green')

# plano para base inferior da árvore 2
a = 10
e = 0
# parâmetros
theta = np.linspace(0, 2*np.pi, 30)
r = np.linspace(0, a, 30)
r, theta = np.meshgrid(r, theta)
# parametrização
x = r*np.cos(theta)
y = r*np.sin(theta)
z = e + 0*r
# gráfico
ax.plot_surface(x, y, z+10, alpha=1, color='green')

# plano para tapete
a = 12
e = 0
# parâmetros
theta = np.linspace(0, 2*np.pi, 30)
r = np.linspace(0, a, 30)
r, theta = np.meshgrid(r, theta)
# parametrização
x = r*np.cos(theta)
y = r*np.sin(theta)
z = e + 0*r
# gráfico
ax.plot_surface(x, y, z, alpha=1, color='red')

# hiperbolóide para vaso
a = 2
# parâmetros
theta = np.linspace(0, 2*np.pi, 10)
v = np.linspace(0, 0.75, 5)
theta, v = np.meshgrid(theta, v)
# parametrização
x = a*np.cos(theta)*np.cosh(v)
y = a*np.sin(theta)*np.cosh(v)
z = (a**2)*np.sinh(v)
# gráfico
ax.plot_surface(x, y, z, alpha=1, color='red')

# cilindro para fitas na árvore
a = 10
b = 10.25
c = 10
# parâmetros
theta = np.linspace(0, 2*np.pi, 30)
z = np.linspace(b, c, 30)
z, theta = np.meshgrid(z, theta)
# parametrização
x = a*np.cos(theta)
y = a*np.sin(theta) 
z = z
# gráfico
ax.plot_surface(x, y, z+0.1, alpha=0.6, color='r')

# cilindro para fitas na árvore
a = 10
b = 5.75
c = 5.5
# parâmetros
theta = np.linspace(0, 2*np.pi, 30)
z = np.linspace(b, c, 30)
z, theta = np.meshgrid(z, theta)
# parametrização
x = a*np.cos(theta)
y = a*np.sin(theta) 
z = z
# gráfico
ax.plot_surface(x, y, z, alpha=0.6, color='r')

# cilindro para fitas na árvore
a = 10
b = 8.25
c = 8
# parâmetros
theta = np.linspace(0, 2*np.pi, 30)
z = np.linspace(b, c, 30)
z, theta = np.meshgrid(z, theta)
# parametrização
x = a*np.cos(theta)
y = a*np.sin(theta) 
z = z
# gráfico
ax.plot_surface(x, y, z, alpha=1, color='goldenrod')

# cilindro para fitas na árvore
a = 10
b = 11.25
c = 11
# parâmetros
theta = np.linspace(0, 2*np.pi, 30)
z = np.linspace(b, c, 30)
z, theta = np.meshgrid(z, theta)
# parametrização
x = a*np.cos(theta)
y = a*np.sin(theta) 
z = z
# gráfico
ax.plot_surface(x, y, z, alpha=1, color='goldenrod')

# cilíndro para presente 1
a = 2
b = 2
c = 0
# parâmetros
theta = np.linspace(0, 2*np.pi, 30)
z = np.linspace(b, c, 30)
z, theta = np.meshgrid(z, theta)
# parametrização
x = a*np.cos(theta)
y = a*np.sin(theta) 
z = z
# gráfico
ax.plot_surface(x, y+10, z, alpha=1, color='red')

# cilíndro para faixa do presente 1
a = 2
b = 1
c = 0
# parâmetros
theta = np.linspace(0, 2*np.pi, 30)
z = np.linspace(b, c, 30)
z, theta = np.meshgrid(z, theta)
# parametrização
x = a*np.cos(theta)
y = a*np.sin(theta) 
z = z
# gráfico
ax.plot_surface(x, y+10, z+1, alpha=1, color='white')

# cílindro para presente 2
a = 2
b = 2
c = 0
# parâmetros
theta = np.linspace(0, 2*np.pi, 30)
z = np.linspace(b, c, 30)
z, theta = np.meshgrid(z, theta)
# parametrização
x = a*np.cos(theta)
y = a*np.sin(theta) 
z = z
# gráfico
ax.plot_surface(x, y-10, z, alpha=1, color='black')

# cilíndro para faixa do presente 2
a = 2
b = 1
c = 0
# parâmetros
theta = np.linspace(0, 2*np.pi, 30)
z = np.linspace(b, c, 30)
z, theta = np.meshgrid(z, theta)
# parametrização
x = a*np.cos(theta)
y = a*np.sin(theta) 
z = z
# gráfico
ax.plot_surface(x, y-10, z+1, alpha=1, color='yellow')

# cilíndro para presente 3
a = 2
b = 2
c = 0
# parâmetros
theta = np.linspace(0, 2*np.pi, 30)
z = np.linspace(b, c, 30)
z, theta = np.meshgrid(z, theta)
# parametrização
x = a*np.cos(theta)
y = a*np.sin(theta) 
z = z
# gráfico
ax.plot_surface(x+10, y, z, alpha=1, color='white')

# cilíndro para faixa do presente 3
a = 2
b = 1
c = 0
# parâmetros
theta = np.linspace(0, 2*np.pi, 30)
z = np.linspace(b, c, 30)
z, theta = np.meshgrid(z, theta)
# parametrização
x = a*np.cos(theta)
y = a*np.sin(theta) 
z = z
# gráfico
ax.plot_surface(x+10, y, z+1, alpha=1, color='green')

# laço abaixo a estrela
a = 1.5
b = 0.25
c = 1
# parâmetros
t = np.linspace(0, 2*np.pi, 30)
theta = np.linspace(0, 2*np.pi, 30)
t , theta = np.meshgrid(t , theta)
# parametrização
y = a*t
x = b*np.sin(t)*np.cos(theta)
z = c*np.sin(t)*np.sin(theta)
# gráfico
ax.plot_surface(x, y-5, z+25, alpha=1, color="chocolate")

# cone para ponta da estrela (superior)
a = 10
b = 1
c = 2  # comprimento
# parâmetros
theta = np.linspace(0, 2*np.pi, 30)
r = np.linspace(0, 1, 30)
theta, r = np.meshgrid(theta, r)
# parametrização
x = b*r*np.cos(theta)
y = b*r*np.sin(theta)
z = -c*r
#gráfico
ax.plot_surface(x, y, z+29, alpha=1, color='gold')

# cone para ponta da estrela (inferior)
a = 10
b = 1
c = 2  # comprimento
# parâmetros
theta = np.linspace(0, 2*np.pi, 30)
r = np.linspace(0, 1, 30)
theta, r = np.meshgrid(theta, r)
# parametrização
x = b*r*np.cos(theta)
y = b*r*np.sin(theta)
z = c*r
#gráfico
ax.plot_surface(x, y, z+25, alpha=1, color='gold')

# cone para ponta da estrela (lateral 1)
a = 10
b = 1
c = 2  # comprimento
# parâmetros
theta = np.linspace(0, 2*np.pi, 30)
r = np.linspace(0, 1, 30)
theta, r = np.meshgrid(theta, r)
# parametrização
z = b*r*np.cos(theta)
y = b*r*np.sin(theta)
x = -c*r
#gráfico
ax.plot_surface(x+2, y, z+27, alpha=1, color='gold')

# cone para ponta da estrela (lateral 2)
a = 10
b = 1
c = 2  # comprimento
# parâmetros
theta = np.linspace(0, 2*np.pi, 30)
r = np.linspace(0, 1, 30)
theta, r = np.meshgrid(theta, r)
# parametrização
z = b*r*np.cos(theta)
y = b*r*np.sin(theta)
x = c*r
#gráfico
ax.plot_surface(x-2, y, z+27, alpha=1, color='gold')

# cone para ponta da estrela (lateral 3)
a = 10
b = 1
c = 2  # comprimento
# parâmetros
theta = np.linspace(0, 2*np.pi, 30)
r = np.linspace(0, 1, 30)
theta, r = np.meshgrid(theta, r)
# parametrização
x = b*r*np.cos(theta)
z = b*r*np.sin(theta)
y = c*r
#gráfico
ax.plot_surface(x, y-2, z+27, alpha=1, color='gold')

# cone para ponta da estrela (lateral 4)
a = 10
b = 1
c = 2  # comprimento
# parâmetros
theta = np.linspace(0, 2*np.pi, 30)
r = np.linspace(0, 1, 30)
theta, r = np.meshgrid(theta, r)
# parametrização
x = b*r*np.cos(theta)
z = b*r*np.sin(theta)
y = -c*r
#gráfico
ax.plot_surface(x, y+2, z+27, alpha=1, color='gold')

# toro para apoio dos "postes" (maior)
a = 1
b = 5
# parâmetros
theta = np.linspace(0 , 2*np.pi, 30)
alp = np.linspace(0, 2*np.pi, 30)
theta, alp = np.meshgrid(theta, alp)
# parametrização
x = (b + a*np.cos(alp))*np.cos(theta)
y = (b + a*np.cos(alp))*np.sin(theta)
z = a*np.sin(alp)
# gráfico
ax.plot_surface(x-8, y+18, z , alpha=1, color="aliceblue")

# tubo espiral para "postes de doce" (maior)
a = 2
b = 5
# parâmetros
u = np.linspace(0, 8*np.pi, 30)
v = np.linspace(0, 2*np.pi, 30)
u , v = np.meshgrid(u , v)
# parametrização
x = (a + np.sin(v))*np.cos(u)
y = (b + np.sin(v))*np.sin(u)
z = u + np.cos(v)
# gráfico
ax.plot_surface(x-8, y+18, z, alpha=1, color="red")

# toro para apoio dos "postes" (menor)
a = 1
b = 5
# parâmetros
theta = np.linspace(0 , 2*np.pi, 30)
alp = np.linspace(0, 2*np.pi, 30)
theta, alp = np.meshgrid(theta, alp)
# parametrização
x = (b + a*np.cos(alp))*np.cos(theta)
y = (b + a*np.cos(alp))*np.sin(theta)
z = a*np.sin(alp)
# gráfico
ax.plot_surface(x+8, y-18, z , alpha=1, color="red")

# tubo espiral para "postes de doce" (menor)
a = 2
b = 5
# parâmetros
u = np.linspace(0, 6*np.pi, 30)
v = np.linspace(0, 2*np.pi, 30)
u , v = np.meshgrid(u , v)
# parametrização
x = (a + np.sin(v))*np.cos(u)
y = (b + np.sin(v))*np.sin(u)
z = u + np.cos(v)
# gráfico
ax.plot_surface(x+8, y-18, z, alpha=1, color="aliceblue")

# fita de Möbius
a = 10
b = 10
# parâmetros
r = np.linspace(-1/2 , 1/2 , 30)
theta = np.linspace(0, 2*np.pi, 30)
r , theta = np.meshgrid(r, theta)
# parametrização
x = a*np.cos(theta) + r*np.cos(theta/2)
y = b*np.sin(theta) + r*np.cos(theta/2)
z = r*np.sin(theta/2)
# gráfico
ax.plot_surface(x, y, z+10, alpha=1, color="deeppink")

# esfera para a enfeites
rho = 0.5
# parâmetros
phi = np.linspace(0, np.pi, 30)
theta = np.linspace(0, 2*np.pi, 30)
phi, theta = np.meshgrid(phi, theta)
# parametrização
x = rho*np.sin(phi)*np.cos(theta) 
y = rho*np.sin(phi)*np.sin(theta) 
z = rho*np.cos(phi)
# gráfico
ax.plot_surface(x+4, y, z+20, alpha=1, color='darkblue')

# esfera para a enfeites
rho = 0.5
# parâmetros
phi = np.linspace(0, np.pi, 30)
theta = np.linspace(0, 2*np.pi, 30)
phi, theta = np.meshgrid(phi, theta)
# parametrização
x = rho*np.sin(phi)*np.cos(theta) 
y = rho*np.sin(phi)*np.sin(theta) 
z = rho*np.cos(phi)
# gráfico
ax.plot_surface(x-4, y-1, z+20, alpha=1, color='orange')

# esfera para a enfeites
rho = 0.5
# parâmetros
phi = np.linspace(0, np.pi, 30)
theta = np.linspace(0, 2*np.pi, 30)
phi, theta = np.meshgrid(phi, theta)
# parametrização
x = rho*np.sin(phi)*np.cos(theta) 
y = rho*np.sin(phi)*np.sin(theta) 
z = rho*np.cos(phi)
# gráfico
ax.plot_surface(x, y-4, z+20, alpha=1, color='red')

# esfera para a enfeites
rho = 0.5
# parâmetros
phi = np.linspace(0, np.pi, 30)
theta = np.linspace(0, 2*np.pi, 30)
phi, theta = np.meshgrid(phi, theta)
# parametrização
x = rho*np.sin(phi)*np.cos(theta) 
y = rho*np.sin(phi)*np.sin(theta) 
z = rho*np.cos(phi)
# gráfico
ax.plot_surface(x, y+4, z+20, alpha=1, color='deepskyblue')

# esfera para a enfeites
rho = 0.5
# parâmetros
phi = np.linspace(0, np.pi, 30)
theta = np.linspace(0, 2*np.pi, 30)
phi, theta = np.meshgrid(phi, theta)
# parametrização
x = rho*np.sin(phi)*np.cos(theta) 
y = rho*np.sin(phi)*np.sin(theta) 
z = rho*np.cos(phi)
# gráfico
ax.plot_surface(x, y-7, z+15, alpha=1, color='red')

# esfera para a enfeites
rho = 0.5
# parâmetros
phi = np.linspace(0, np.pi, 30)
theta = np.linspace(0, 2*np.pi, 30)
phi, theta = np.meshgrid(phi, theta)
# parametrização
x = rho*np.sin(phi)*np.cos(theta) 
y = rho*np.sin(phi)*np.sin(theta) 
z = rho*np.cos(phi)
# gráfico
ax.plot_surface(x, y+7, z+15, alpha=1, color='orchid')

# esfera para a enfeites
rho = 0.5
# parâmetros
phi = np.linspace(0, np.pi, 30)
theta = np.linspace(0, 2*np.pi, 30)
phi, theta = np.meshgrid(phi, theta)
# parametrização
x = rho*np.sin(phi)*np.cos(theta) 
y = rho*np.sin(phi)*np.sin(theta) 
z = rho*np.cos(phi)
# gráfico
ax.plot_surface(x-7, y, z+15, alpha=1, color='aqua')

# esfera para a enfeites
rho = 0.5
# parâmetros
phi = np.linspace(0, np.pi, 30)
theta = np.linspace(0, 2*np.pi, 30)
phi, theta = np.meshgrid(phi, theta)
# parametrização
x = rho*np.sin(phi)*np.cos(theta) 
y = rho*np.sin(phi)*np.sin(theta) 
z = rho*np.cos(phi)
# gráfico
ax.plot_surface(x+7, y, z+15, alpha=1, color='yellow')

# título
plt.title("FELIZ NATAL! (Mesmo que já tenha passado :D)")
# remove marcações nos eixos x, y, z
#ax.set_xticks([])  # comentar para montar teu desenho: visualizar os eixos torna a criação mais fácil
#ax.set_yticks([])  # comentar para montar teu desenho: visualizar os eixos torna a criação mais fácil
#ax.set_zticks([])  # comentar para montar teu desenho: visualizar os eixos torna a criação mais fácil

# limite dos eixos x e y
plt.xlim([-20, 20])  
plt.ylim([-20, 20])

# Fundo invisível
ax.xaxis.pane.fill = False
ax.yaxis.pane.fill = False
ax.zaxis.pane.fill = False
ax.xaxis.pane.set_edgecolor('w')
ax.yaxis.pane.set_edgecolor('w')
ax.zaxis.pane.set_edgecolor('w')

# ângulo de visualização
ax.view_init(0,240)

plt.show()

# %%
# Parte 2

# %matplotlib inline

# bibliotecas
from mpl_toolkits import mplot3d
import numpy as np
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(8,8))
ax = plt.axes(projection='3d')

# esfera para a enfeites
rho = 0.5
# parâmetros
phi = np.linspace(0, np.pi, 30)
theta = np.linspace(0, 2*np.pi, 30)
phi, theta = np.meshgrid(phi, theta)
# parametrização
x = rho*np.sin(phi)*np.cos(theta) 
y = rho*np.sin(phi)*np.sin(theta) 
z = rho*np.cos(phi)
# gráfico
ax.plot_surface(x+4, y, z+20, alpha=1, color='darkblue')

plt.title("Superfície S")
ax.set_xlabel('eixo x')
ax.set_ylabel('eixo y')
ax.set_zlabel('eixo z')
plt.show()

# %% [markdown]
# ![Imagem MA2 (ESFERA) (cortado).jpg](data:image/jpeg;base64,...)

# %%
# norma do produto vetorial: |ru x rv| avaliada no ponto (ui, vj) da discretização
# (u, v): parâmetros da parametrização da superfície
# (u, v): (phi, theta)     
def Norma_Produto_Vetorial(rho, phi, theta):  
    return (rho**2)*np.sin(phi) 

# Definir o domínio D (retangular)
# variação do u (phi)
a = 0
b = np.pi
# variação do v (theta)
c = 0
d = 2*np.pi

# discretização
n = 99
m = 99
deltau = (b-a)/n
deltav = (d-c)/m

# cria um arranjo de números
# np.arange(minimo, maximo, passo)
# começa em "minimo" vai até < "máximo", de passo em passo 
u = np.arange(a, b+deltau, deltau)  # mínimo, máximo, passo
v = np.arange(c, d+deltav, deltav)  # mínimo, máximo, passo

# cálculo da área: soma dupla -> 2 for aninhados
area = 0
rho = 0.5
for i in range(n):       # primeiro somatório
    ponto_medio_u = (u[i] + u[i+1])/2
    for j in range(m):   # segundo somatório
        ponto_medio_v = (v[j] + v[j+1])/2
        npv = Norma_Produto_Vetorial(rho, ponto_medio_u, ponto_medio_v)
        area = area + npv*deltau*deltav
print("Área da superfície S: %.2f" %area)
# Out:
# Área da superfície S: 3.14

# %%
# vamos confirmar se a aproximação está correta?
import sympy as sp

f, t = sp.symbols('f t')   # phi e theta

rho = 0.5
areaS = sp.integrate(sp.integrate((rho**2)*sp.sin(f), (f,0,sp.pi)), (t,0,2*sp.pi))
print("Área da superfície S: %.2f" %areaS)
# Out:
# Área da superfície S: 3.14

# %%
# %matplotlib inline

# bibliotecas
from mpl_toolkits import mplot3d
import numpy as np
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(8,8))
ax = plt.axes(projection='3d')

# cilíndro para tronco 
a = 2
b = 10
c = 0
# parâmetros
theta = np.linspace(0, 2*np.pi, 30)
z = np.linspace(b, c, 30)
z, theta = np.meshgrid(z, theta)
# parametrização
x = a*np.cos(theta)
y = a*np.sin(theta) 
z = z
# gráfico
ax.plot_surface(x, y, z, alpha=1, color='saddlebrown')

plt.title("Superfície S")
ax.set_xlabel('eixo x')
ax.set_ylabel('eixo y')
ax.set_zlabel('eixo z')
plt.show()

# %% [markdown]
# ![Imagem MA2 (CILINDRO) CORTADO.jpg](data:image/jpeg;base64,...)

# %%
# norma do produto vetorial: |ru x rv| avaliada no ponto (ui, vj) da discretização
# (u, v): parâmetros da parametrização da superfície
# (u, v): (z, theta)     
def Norma_Produto_Vetorial(a, z, theta):  
    return a

# Definir o domínio D (retangular)
# variação do u (z)
a = 10
b = 0
# variação do v (theta)
c = 0
d = 2*np.pi

# discretização
n = 100
m = 100
deltau = (b-a)/n
deltav = (d-c)/m

# cria um arranjo de números
# np.arange(minimo, maximo, passo)
# começa em "minimo" vai até < "máximo", de passo em passo 
u = np.arange(a, b+deltau, deltau)  # mínimo, máximo, passo
v = np.arange(c, d+deltav, deltav)  # mínimo, máximo, passo

# cálculo da área: soma dupla -> 2 for aninhados
area = 0
a = 2
for i in range(n):       # primeiro somatório
    ponto_medio_u = (u[i] + u[i+1])/2
    for j in range(m):   # segundo somatório
        ponto_medio_v = (v[j] + v[j+1])/2
        npv = Norma_Produto_Vetorial(a, ponto_medio_u, ponto_medio_v)
        area = area + npv*deltau*deltav
print("Área da superfície S: %.2f" %area) # ver módulo
# Out:
# Área da superfície S: -125.66

# %%
# vamos confirmar se a aproximação está correta?
import sympy as sp

z, t = sp.symbols('z t')   # z e theta

a = 2
areaS = sp.integrate(sp.integrate(a, (t,0,2*sp.pi)), (z,10,0))
print("Área da superfície S: %.2f" %areaS) # ver módulo
# Out:
# Área da superfície S: -125.66
